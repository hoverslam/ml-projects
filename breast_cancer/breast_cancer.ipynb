# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import neighbors
from sklearn import svm

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data set

# %%
train = pd.read_csv("breast_cancer_train.csv")
test = pd.read_csv("breast_cancer_test.csv")
train.head()
# Out:
#          ID  class  radiusMean   textureMean   perimeterMean   areaMean  \
# 0    913102  False      14.640         16.85           94.21      666.0
# 1  89511501  False      12.200         15.21           78.01      457.9
# 2     87163   True      13.430         19.63           85.84      565.4
# 3    894047  False       8.597         18.60           54.09      221.2
# 4     86409  False      14.260         19.65           97.83      629.9
#
#     smoothnessMean   compactnessMean   concavityMean   concavePointsMean  ...  \
# 0          0.08641           0.06698         0.05192             0.02791  ...
# 1          0.08673           0.06545         0.01994             0.01692  ...
# 2          0.09048           0.06288         0.05858             0.03438  ...
# 3          0.10740           0.05847         0.00000             0.00000  ...
# 4          0.07837           0.22330         0.30030             0.07798  ...
#
#     radiusWorst   textureWorst   perimeterWorst   areaWorst   smoothnessWorst  \
# 0        16.460          25.44           106.00       831.0           0.11420
# 1        13.750          21.38            91.11       583.1           0.12560
# 2        17.980          29.87           116.60       993.6           0.14010
# 3         8.952          22.44            56.65       240.1           0.13470
# 4        15.300          23.73           107.00       709.0           0.08949
#
#     compactnessWorst   concavityWorst   concavePointsWorst   symmetryWorst  \
# 0            0.20700           0.2437              0.07828          0.2455
# 1            0.19280           0.1167              0.05556          0.2661
# 2            0.15460           0.2644              0.11600          0.2884
# 3            0.07767           0.0000              0.00000          0.3142
# 4            0.41930           0.6783              0.15050          0.2398
#
#     fractalDimensionWorst
# 0                 0.06596
# 1                 0.07961
# 2                 0.07371
# 3                 0.08116
# 4                 0.10820
#
# [5 rows x 32 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       285 non-null    int64
#  1   class                    285 non-null    bool
#  2   radiusMean               285 non-null    float64
#  3    textureMean             285 non-null    float64
#  4    perimeterMean           285 non-null    float64
#  5    areaMean                285 non-null    float64
#  6    smoothnessMean          285 non-null    float64
#  7    compactnessMean         285 non-null    float64
#  8    concavityMean           285 non-null    float64
#  9    concavePointsMean       285 non-null    float64
#  10   symmetryMean            285 non-null    float64
#  11   fractalDimensionMean    285 non-null    float64
#  12   radiusStdErr            285 non-null    float64
#  13   textureStdErr           285 non-null    float64
#  14   perimeterStdErr         285 non-null    float64
#  15   areaStdErr              285 non-null    float64
#  16   smoothnessStdErr        285 non-null    float64
#  17   compactnessStdErr       285 non-null    float64
#  18   concavityStdErr         285 non-null    float64
#  19   concavePointsStdErr     285 non-null    float64
#  20   symmetryStdErr          285 non-null    float64
#  21   fractalDimensionStdErr  285 non-null    float64
#  22   radiusWorst             285 non-null    float64
#  23   textureWorst            285 non-null    float64
#  24   perimeterWorst          285 non-null    float64
#  25   areaWorst               285 non-null    float64
#  26   smoothnessWorst         285 non-null    float64
#  27   compactnessWorst        285 non-null    float64
#  28   concavityWorst          285 non-null    float64
#  29   concavePointsWorst      285 non-null    float64
#  30   symmetryWorst           285 non-null    float64
#  31   fractalDimensionWorst   285 non-null    float64
# dtypes: bool(1), float64(30), int64(1)
# memory usage: 69.4 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       284 non-null    int64
#  1   radiusMean               284 non-null    float64
#  2    textureMean             284 non-null    float64
#  3    perimeterMean           284 non-null    float64
#  4    areaMean                284 non-null    float64
#  5    smoothnessMean          284 non-null    float64
#  6    compactnessMean         284 non-null    float64
#  7    concavityMean           284 non-null    float64
#  8    concavePointsMean       284 non-null    float64
#  9    symmetryMean            284 non-null    float64
#  10   fractalDimensionMean    284 non-null    float64
#  11   radiusStdErr            284 non-null    float64
#  12   textureStdErr           284 non-null    float64
#  13   perimeterStdErr         284 non-null    float64
#  14   areaStdErr              284 non-null    float64
#  15   smoothnessStdErr        284 non-null    float64
#  16   compactnessStdErr       284 non-null    float64
#  17   concavityStdErr         284 non-null    float64
#  18   concavePointsStdErr     284 non-null    float64
#  19   symmetryStdErr          284 non-null    float64
#  20   fractalDimensionStdErr  284 non-null    float64
#  21   radiusWorst             284 non-null    float64
#  22   textureWorst            284 non-null    float64
#  23   perimeterWorst          284 non-null    float64
#  24   areaWorst               284 non-null    float64
#  25   smoothnessWorst         284 non-null    float64
#  26   compactnessWorst        284 non-null    float64
#  27   concavityWorst          284 non-null    float64
#  28   concavePointsWorst      284 non-null    float64
#  29   symmetryWorst           284 non-null    float64
#  30   fractalDimensionWorst   284 non-null    float64
# dtypes: float64(30), int64(1)
# memory usage: 68.9 KB

# %%
X = train.drop(["ID", "class"], axis=1)
y = train["class"]

X_test = test.drop(["ID"], axis=1)

# %%
X.head()
# Out:
#    radiusMean   textureMean   perimeterMean   areaMean   smoothnessMean  \
# 0      14.640         16.85           94.21      666.0          0.08641
# 1      12.200         15.21           78.01      457.9          0.08673
# 2      13.430         19.63           85.84      565.4          0.09048
# 3       8.597         18.60           54.09      221.2          0.10740
# 4      14.260         19.65           97.83      629.9          0.07837
#
#     compactnessMean   concavityMean   concavePointsMean   symmetryMean  \
# 0           0.06698         0.05192             0.02791         0.1409
# 1           0.06545         0.01994             0.01692         0.1638
# 2           0.06288         0.05858             0.03438         0.1598
# 3           0.05847         0.00000             0.00000         0.2163
# 4           0.22330         0.30030             0.07798         0.1704
#
#     fractalDimensionMean  ...   radiusWorst   textureWorst   perimeterWorst  \
# 0                0.05355  ...        16.460          25.44           106.00
# 1                0.06129  ...        13.750          21.38            91.11
# 2                0.05671  ...        17.980          29.87           116.60
# 3                0.07359  ...         8.952          22.44            56.65
# 4                0.07769  ...        15.300          23.73           107.00
#
#     areaWorst   smoothnessWorst   compactnessWorst   concavityWorst  \
# 0       831.0           0.11420            0.20700           0.2437
# 1       583.1           0.12560            0.19280           0.1167
# 2       993.6           0.14010            0.15460           0.2644
# 3       240.1           0.13470            0.07767           0.0000
# 4       709.0           0.08949            0.41930           0.6783
#
#     concavePointsWorst   symmetryWorst   fractalDimensionWorst
# 0              0.07828          0.2455                 0.06596
# 1              0.05556          0.2661                 0.07961
# 2              0.11600          0.2884                 0.07371
# 3              0.00000          0.3142                 0.08116
# 4              0.15050          0.2398                 0.10820
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: class, dtype: bool

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Overview

# %%
X.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Plots

# %%
# [TODO]

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Feature selection

# %%
# [TODO]

# %% [markdown]
# ## Feature scaling

# %%
# [TODO]

# %% [markdown]
# ## Encoding

# %%
# [TODO]

# %% [markdown]
# # Model selection

# %%
cv = 10
verbose = 3

# %% [markdown]
# ## KNN

# %%
parameters = {"n_neighbors":[1, 5, 10, 20, 30, 40, 50], "weights":["uniform", "distance"]}
knn = GridSearchCV(neighbors.KNeighborsClassifier(), parameters, cv=cv, verbose=verbose)
knn.fit(X, y)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   0.0s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=10, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=10, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=10, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=10, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=10, weights=uniform; total time=   0.0s
# [CV] END ...................n_neighbors=10, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=10, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=10, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=10, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=10, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=20, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=20, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=20, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=20, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=20, weights=uniform; total time=   0.0s
# [CV] END ...................n_neighbors=20, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=20, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=20, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=20, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=20, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=30, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=30, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=30, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=30, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=30, weights=uniform; total time=   0.0s
# [CV] END ...................n_neighbors=30, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=30, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=30, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=30, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=30, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=40, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=40, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=40, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=40, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=40, weights=uniform; total time=   0.0s
# [CV] END ...................n_neighbors=40, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=40, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=40, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=40, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=40, weights=distance; total time=   0.0s
# [CV] END ....................n_neighbors=50, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=50, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=50, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=50, weights=uniform; total time=   0.0s
# [CV] END ....................n_neighbors=50, weights=uniform; total time=   0.0s
# [CV] END ...................n_neighbors=50, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=50, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=50, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=50, weights=distance; total time=   0.0s
# [CV] END ...................n_neighbors=50, weights=distance; total time=   0.0s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 5, 10, 20, 30, 40, 50],
#                          'weights': ['uniform', 'distance']},
#              verbose=2)

# %%
knn_results = pd.DataFrame(knn.cv_results_)
knn_results[["param_n_neighbors", "param_weights", "mean_test_score"]]
# Out:
#    param_n_neighbors param_weights  mean_test_score
# 0                  1       uniform          0.34325
# 1                  1      distance          0.34325
# 2                  5       uniform          0.38850
# 3                  5      distance          0.41200
# 4                 10       uniform          0.43400
# 5                 10      distance          0.44850
# 6                 20       uniform          0.46625
# 7                 20      distance          0.48325
# 8                 30       uniform          0.48350
# 9                 30      distance          0.49425
# 10                40       uniform          0.48700
# 11                40      distance          0.49950
# 12                50       uniform          0.48675
# 13                50      distance          0.49800

# %% [markdown]
# ## Decision Tree

# %%
parameters = {"n_estimators":[100, 200, 300, 400, 500], "criterion":["gini", "entropy"], "max_depth":["None", 10, 20]}
dt = GridSearchCV(RandomForestClassifier(), parameters, cv=cv, verbose=verbose)
dt.fit(X, y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.2s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.2s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.1s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.1s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.1s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.9s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.5s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   3.2s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.9s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.9s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.4s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.4s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.3s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.3s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.3s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.3s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.1s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.1s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.1s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.4s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.5s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.7s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.7s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.7s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.7s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.6s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.9s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.6s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.5s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.6s
# f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 50 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\ensemble\_forest.py", line 442, in fit
#     trees = Parallel(
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\utils\fixes.py", line 211, in __call__
#     return self.function(*args, **kwargs)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\tree\_classes.py", line 305, in fit
#     if max_depth <= 0:
# TypeError: '<=' not supported between instances of 'str' and 'int'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [    nan     nan     nan     nan     nan 0.49625 0.496   0.49525 0.5055
#  0.50075 0.5365  0.548   0.5605  0.5615  0.56575     nan     nan     nan
#      nan     nan 0.50775 0.51975 0.5265  0.52975 0.52775 0.5255  0.5555
#  0.5545  0.55725 0.565  ]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': ['None', 10, 20],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=2)

# %%
dt_results = pd.DataFrame(dt.cv_results_)
dt_results[["param_n_estimators", "param_criterion", "param_max_depth", "mean_test_score"]]
# Out:
#    param_n_estimators param_criterion param_max_depth  mean_test_score
# 0                 100            gini            None              NaN
# 1                 200            gini            None              NaN
# 2                 300            gini            None              NaN
# 3                 400            gini            None              NaN
# 4                 500            gini            None              NaN
# 5                 100            gini              10          0.49625
# 6                 200            gini              10          0.49600
# 7                 300            gini              10          0.49525
# 8                 400            gini              10          0.50550
# 9                 500            gini              10          0.50075
# 10                100            gini              20          0.53650
# 11                200            gini              20          0.54800
# 12                300            gini              20          0.56050
# 13                400            gini              20          0.56150
# 14                500            gini              20          0.56575
# 15                100         entropy            None              NaN
# 16                200         entropy            None              NaN
# 17                300         entropy            None              NaN
# 18                400         entropy            None              NaN
# 19                500         entropy            None              NaN
# 20                100         entropy              10          0.50775
# 21                200         entropy              10          0.51975
# 22                300         entropy              10          0.52650
# 23                400         entropy              10          0.52975
# 24                500         entropy              10          0.52775
# 25                100         entropy              20          0.52550
# 26                200         entropy              20          0.55550
# 27                300         entropy              20          0.55450
# 28                400         entropy              20          0.55725
# 29                500         entropy              20          0.56500

# %% [markdown]
# ## Random Forest

# %%
parameters = {"n_estimators":[100, 200, 300, 400, 500], "criterion":["gini", "entropy"], "max_depth":["None", 10, 20]}
rf = GridSearchCV(RandomForestClassifier(), parameters, cv=cv, verbose=verbose)
rf.fit(X, y)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ...criterion=gini, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=400; total time=   1.8s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.3s
# [CV] END .....criterion=gini, max_depth=10, n_estimators=500; total time=   2.3s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=200; total time=   1.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=300; total time=   2.7s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.8s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.6s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.5s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=400; total time=   3.5s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.3s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.4s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.4s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.2s
# [CV] END .....criterion=gini, max_depth=20, n_estimators=500; total time=   4.3s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=100; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=200; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=300; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=400; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END criterion=entropy, max_depth=None, n_estimators=500; total time=   0.0s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=100; total time=   0.6s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.3s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=200; total time=   1.2s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.8s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.8s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=300; total time=   1.9s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.5s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.5s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.5s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.5s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=400; total time=   2.5s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.0s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.0s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.1s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.1s
# [CV] END ..criterion=entropy, max_depth=10, n_estimators=500; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.1s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=100; total time=   1.1s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=200; total time=   2.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.2s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=300; total time=   3.4s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.8s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.7s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.5s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.3s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=400; total time=   4.5s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.7s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.6s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   6.0s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   6.1s
# [CV] END ..criterion=entropy, max_depth=20, n_estimators=500; total time=   5.9s
# f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 50 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\ensemble\_forest.py", line 442, in fit
#     trees = Parallel(
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\utils\fixes.py", line 211, in __call__
#     return self.function(*args, **kwargs)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\tree\_classes.py", line 305, in fit
#     if max_depth <= 0:
# TypeError: '<=' not supported between instances of 'str' and 'int'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# f:\Programmieren\Python\ml-projects\.venv\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [    nan     nan     nan     nan     nan 0.48425 0.498   0.5025  0.4965
#  0.4985  0.529   0.554   0.557   0.56375 0.56825     nan     nan     nan
#      nan     nan 0.50025 0.51725 0.5275  0.528   0.53325 0.5255  0.543
#  0.56075 0.56225 0.5605 ]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': ['None', 10, 20],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=2)

# %%
rf_results = pd.DataFrame(rf.cv_results_)
rf_results[["param_n_estimators", "param_criterion", "param_max_depth", "mean_test_score"]]
# Out:
#    param_n_estimators param_criterion param_max_depth  mean_test_score
# 0                 100            gini            None              NaN
# 1                 200            gini            None              NaN
# 2                 300            gini            None              NaN
# 3                 400            gini            None              NaN
# 4                 500            gini            None              NaN
# 5                 100            gini              10          0.48425
# 6                 200            gini              10          0.49800
# 7                 300            gini              10          0.50250
# 8                 400            gini              10          0.49650
# 9                 500            gini              10          0.49850
# 10                100            gini              20          0.52900
# 11                200            gini              20          0.55400
# 12                300            gini              20          0.55700
# 13                400            gini              20          0.56375
# 14                500            gini              20          0.56825
# 15                100         entropy            None              NaN
# 16                200         entropy            None              NaN
# 17                300         entropy            None              NaN
# 18                400         entropy            None              NaN
# 19                500         entropy            None              NaN
# 20                100         entropy              10          0.50025
# 21                200         entropy              10          0.51725
# 22                300         entropy              10          0.52750
# 23                400         entropy              10          0.52800
# 24                500         entropy              10          0.53325
# 25                100         entropy              20          0.52550
# 26                200         entropy              20          0.54300
# 27                300         entropy              20          0.56075
# 28                400         entropy              20          0.56225
# 29                500         entropy              20          0.56050

# %% [markdown]
# ## SVM

# %%
parameters = {"kernel":["sigmoid", "rbf"], "C":[1, 5, 10, 20], "gamma":["scale", "auto"]}
svm = GridSearchCV(svm.SVC(), parameters, cv=cv, verbose=verbose)
svm.fit(X, y)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [CV 1/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.680 total time=   1.5s
# [CV 2/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.762 total time=   1.6s
# [CV 3/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.682 total time=   1.5s
# [CV 4/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.725 total time=   1.5s
# [CV 5/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.713 total time=   1.5s
# [CV 6/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.693 total time=   1.5s
# [CV 7/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.705 total time=   1.5s
# [CV 8/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.698 total time=   1.5s
# [CV 9/10] END .C=1, gamma=scale, kernel=sigmoid;, score=0.700 total time=   1.5s
# [CV 10/10] END C=1, gamma=scale, kernel=sigmoid;, score=0.685 total time=   1.5s
# [CV 1/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.675 total time=   2.9s
# [CV 2/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.743 total time=   3.0s
# [CV 3/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.680 total time=   3.0s
# [CV 4/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.695 total time=   3.0s
# [CV 5/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.690 total time=   3.0s
# [CV 6/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.698 total time=   2.9s
# [CV 7/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.703 total time=   2.9s
# [CV 8/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.685 total time=   2.8s
# [CV 9/10] END .....C=1, gamma=scale, kernel=rbf;, score=0.700 total time=   2.7s
# [CV 10/10] END ....C=1, gamma=scale, kernel=rbf;, score=0.675 total time=   2.7s
# [CV 1/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.412 total time=   2.4s
# [CV 2/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.430 total time=   2.5s
# [CV 3/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.400 total time=   2.5s
# [CV 4/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.453 total time=   2.5s
# [CV 5/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.445 total time=   2.4s
# [CV 6/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.430 total time=   2.4s
# [CV 7/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.410 total time=   2.3s
# [CV 8/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.435 total time=   2.3s
# [CV 9/10] END ..C=1, gamma=auto, kernel=sigmoid;, score=0.420 total time=   2.3s
# [CV 10/10] END .C=1, gamma=auto, kernel=sigmoid;, score=0.425 total time=   2.3s
# [CV 1/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.578 total time=   2.3s
# [CV 2/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.598 total time=   2.3s
# [CV 3/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.575 total time=   2.4s
# [CV 4/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.610 total time=   2.3s
# [CV 5/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.620 total time=   2.3s
# [CV 6/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.620 total time=   2.3s
# [CV 7/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.583 total time=   2.3s
# [CV 8/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.603 total time=   2.3s
# [CV 9/10] END ......C=1, gamma=auto, kernel=rbf;, score=0.578 total time=   2.3s
# [CV 10/10] END .....C=1, gamma=auto, kernel=rbf;, score=0.570 total time=   2.3s
# [CV 1/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.710 total time=   1.0s
# [CV 2/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.743 total time=   1.1s
# [CV 3/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.657 total time=   1.0s
# [CV 4/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.708 total time=   1.1s
# [CV 5/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.693 total time=   1.1s
# [CV 6/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.665 total time=   1.1s
# [CV 7/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.695 total time=   1.1s
# [CV 8/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.680 total time=   1.2s
# [CV 9/10] END .C=5, gamma=scale, kernel=sigmoid;, score=0.672 total time=   1.1s
# [CV 10/10] END C=5, gamma=scale, kernel=sigmoid;, score=0.660 total time=   1.2s
# [CV 1/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.682 total time=   2.9s
# [CV 2/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.755 total time=   2.8s
# [CV 3/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.703 total time=   2.8s
# [CV 4/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.720 total time=   2.8s
# [CV 5/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.713 total time=   2.8s
# [CV 6/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.723 total time=   2.8s
# [CV 7/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.700 total time=   2.8s
# [CV 8/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.713 total time=   2.8s
# [CV 9/10] END .....C=5, gamma=scale, kernel=rbf;, score=0.728 total time=   2.8s
# [CV 10/10] END ....C=5, gamma=scale, kernel=rbf;, score=0.700 total time=   2.8s
# [CV 1/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.680 total time=   1.5s
# [CV 2/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.745 total time=   1.5s
# [CV 3/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.695 total time=   1.5s
# [CV 4/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.688 total time=   1.6s
# [CV 5/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.682 total time=   1.5s
# [CV 6/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.693 total time=   1.5s
# [CV 7/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.685 total time=   1.5s
# [CV 8/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.720 total time=   1.6s
# [CV 9/10] END ..C=5, gamma=auto, kernel=sigmoid;, score=0.708 total time=   1.5s
# [CV 10/10] END .C=5, gamma=auto, kernel=sigmoid;, score=0.685 total time=   1.5s
# [CV 1/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.667 total time=   1.7s
# [CV 2/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.767 total time=   1.7s
# [CV 3/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.693 total time=   1.6s
# [CV 4/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.720 total time=   1.7s
# [CV 5/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.695 total time=   1.7s
# [CV 6/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.703 total time=   1.6s
# [CV 7/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.700 total time=   1.7s
# [CV 8/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.713 total time=   1.7s
# [CV 9/10] END ......C=5, gamma=auto, kernel=rbf;, score=0.705 total time=   1.7s
# [CV 10/10] END .....C=5, gamma=auto, kernel=rbf;, score=0.685 total time=   1.7s
# [CV 1/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.640 total time=   1.0s
# [CV 2/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.728 total time=   1.0s
# [CV 3/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.652 total time=   1.0s
# [CV 4/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.685 total time=   1.0s
# [CV 5/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.665 total time=   1.0s
# [CV 6/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.665 total time=   1.0s
# [CV 7/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.650 total time=   1.0s
# [CV 8/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.672 total time=   1.0s
# [CV 9/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.625 total time=   1.0s
# [CV 10/10] END C=10, gamma=scale, kernel=sigmoid;, score=0.693 total time=   1.0s
# [CV 1/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.682 total time=   2.8s
# [CV 2/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.755 total time=   2.8s
# [CV 3/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.703 total time=   2.8s
# [CV 4/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.720 total time=   2.7s
# [CV 5/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.713 total time=   2.8s
# [CV 6/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.723 total time=   2.8s
# [CV 7/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.700 total time=   2.8s
# [CV 8/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.713 total time=   2.8s
# [CV 9/10] END ....C=10, gamma=scale, kernel=rbf;, score=0.728 total time=   2.8s
# [CV 10/10] END ...C=10, gamma=scale, kernel=rbf;, score=0.700 total time=   2.7s
# [CV 1/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.667 total time=   1.4s
# [CV 2/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.760 total time=   1.4s
# [CV 3/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.690 total time=   1.4s
# [CV 4/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.718 total time=   1.4s
# [CV 5/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.695 total time=   1.4s
# [CV 6/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.708 total time=   1.3s
# [CV 7/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.690 total time=   1.4s
# [CV 8/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.718 total time=   1.4s
# [CV 9/10] END .C=10, gamma=auto, kernel=sigmoid;, score=0.710 total time=   1.3s
# [CV 10/10] END C=10, gamma=auto, kernel=sigmoid;, score=0.693 total time=   1.3s
# [CV 1/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.682 total time=   1.6s
# [CV 2/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.767 total time=   1.6s
# [CV 3/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.688 total time=   1.6s
# [CV 4/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.725 total time=   1.6s
# [CV 5/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.677 total time=   1.6s
# [CV 6/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.708 total time=   1.6s
# [CV 7/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.682 total time=   1.6s
# [CV 8/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.735 total time=   1.6s
# [CV 9/10] END .....C=10, gamma=auto, kernel=rbf;, score=0.698 total time=   1.6s
# [CV 10/10] END ....C=10, gamma=auto, kernel=rbf;, score=0.700 total time=   1.6s
# [CV 1/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.637 total time=   0.9s
# [CV 2/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.688 total time=   0.9s
# [CV 3/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.615 total time=   0.9s
# [CV 4/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.662 total time=   0.9s
# [CV 5/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.650 total time=   0.9s
# [CV 6/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.642 total time=   0.9s
# [CV 7/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.613 total time=   0.9s
# [CV 8/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.625 total time=   0.9s
# [CV 9/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.605 total time=   0.9s
# [CV 10/10] END C=20, gamma=scale, kernel=sigmoid;, score=0.632 total time=   0.9s
# [CV 1/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.682 total time=   2.8s
# [CV 2/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.755 total time=   2.8s
# [CV 3/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.703 total time=   2.8s
# [CV 4/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.720 total time=   2.8s
# [CV 5/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.713 total time=   2.8s
# [CV 6/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.723 total time=   2.8s
# [CV 7/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.700 total time=   2.8s
# [CV 8/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.713 total time=   2.8s
# [CV 9/10] END ....C=20, gamma=scale, kernel=rbf;, score=0.728 total time=   2.8s
# [CV 10/10] END ...C=20, gamma=scale, kernel=rbf;, score=0.700 total time=   2.8s
# [CV 1/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.680 total time=   1.3s
# [CV 2/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.748 total time=   1.3s
# [CV 3/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.682 total time=   1.3s
# [CV 4/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.730 total time=   1.3s
# [CV 5/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.665 total time=   1.2s
# [CV 6/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.693 total time=   1.3s
# [CV 7/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.695 total time=   1.3s
# [CV 8/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.735 total time=   1.3s
# [CV 9/10] END .C=20, gamma=auto, kernel=sigmoid;, score=0.690 total time=   1.3s
# [CV 10/10] END C=20, gamma=auto, kernel=sigmoid;, score=0.698 total time=   1.3s
# [CV 1/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.677 total time=   1.6s
# [CV 2/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.760 total time=   1.6s
# [CV 3/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.693 total time=   1.6s
# [CV 4/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.728 total time=   1.6s
# [CV 5/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.698 total time=   1.6s
# [CV 6/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.698 total time=   1.6s
# [CV 7/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.695 total time=   1.7s
# [CV 8/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.733 total time=   1.6s
# [CV 9/10] END .....C=20, gamma=auto, kernel=rbf;, score=0.690 total time=   1.6s
# [CV 10/10] END ....C=20, gamma=auto, kernel=rbf;, score=0.693 total time=   1.6s
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20], 'gamma': ['scale', 'auto'],
#                          'kernel': ['sigmoid', 'rbf']},
#              verbose=3)

# %%
svm_results = pd.DataFrame(svm.cv_results_)
svm_results = svm_results[["param_C", "param_kernel", "param_gamma", "mean_test_score"]]
svm_results.sort_values(["mean_test_score"], ascending=False)
# Out:
#    param_C param_kernel param_gamma  mean_test_score
# 5        5          rbf       scale          0.71350
# 9       10          rbf       scale          0.71350
# 13      20          rbf       scale          0.71350
# 11      10          rbf        auto          0.70625
# 15      20          rbf        auto          0.70625
# 7        5          rbf        auto          0.70475
# 10      10      sigmoid        auto          0.70475
# 0        1      sigmoid       scale          0.70425
# 14      20      sigmoid        auto          0.70150
# 6        5      sigmoid        auto          0.69800
# 1        1          rbf       scale          0.69425
# 4        5      sigmoid       scale          0.68825
# 8       10      sigmoid       scale          0.66750
# 12      20      sigmoid       scale          0.63700
# 3        1          rbf        auto          0.59325
# 2        1      sigmoid        auto          0.42600

# %% [markdown]
# # Final model

# %%
model = svm.SVC(C=5, kernel="rbf", gamma="scale")
model.fit(X, y)
# Out:
# SVC(C=5)

# %%
predictions = pd.DataFrame(test["ID"])
predictions["class"] = model.predict(X_test)

# %%
predictions.to_csv("location_prediction.csv", index=False)
